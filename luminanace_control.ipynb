# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdgoruds2/AI-_assignment/blob/master/luminanace_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install durable_rules
from durable.lang import ruleset, when_all, m, post, _main_host


if _main_host is not None:
    _main_host._ruleset_directory.clear()

with ruleset('luminanace'):
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='reading'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=200'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='reading'))
  def light(c):
    print('IF {0} {1} {2} THEN light=LED lamp'.format(c.m.sky,c.m.time,c.m.active))

  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='sleeping'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=20'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='sleeping'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='rest'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=30'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='rest'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='movie'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=50'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='morning')&(m.active=='movie'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))




  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='reading'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=400'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='reading'))
  def light(c):
    print('IF {0} {1} {2} THEN light=LED lamp'.format(c.m.sky,c.m.time,c.m.active))

  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='sleeping'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=70'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='sleeping'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='rest'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=100'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='rest'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='movie'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=100'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='sunny')&(m.time=='night')&(m.active=='movie'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))



  
  @when_all((m.sky=='cloudy')&(m.time=='morning')&(m.active=='reading'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=30'.format(c.m.sky,c.m.time,c.m.active))
  def light(c):
    print('IF {0} {1} {2} THEN light=LED lamp'.format(c.m.sky,c.m.time,c.m.active))

  @when_all((m.sky=='cloudy')&(m.time=='morning')&(m.active=='sleeping'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=50'.format(c.m.sky,c.m.time,c.m.active))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='cloudy')&(m.time=='morning')&(m.active=='rest'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=70'.format(c.m.sky,c.m.time,c.m.active))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='cloudy')&(m.time=='morning')&(m.active=='movie'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=70'.format(c.m.sky,c.m.time,c.m.active))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  



  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='reading'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=400'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='reading'))
  def light(c):
    print('IF {0} {1} {2} THEN light=LED lamp'.format(c.m.sky,c.m.time,c.m.active))

  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='sleeping'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=70'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='sleeping'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='rest'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=100'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='rest'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))
  
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='movie'))
  def lux(c):
    print('IF {0} {1} {2} THEN lux=100'.format(c.m.sky,c.m.time,c.m.active))
  @when_all((m.sky=='cloudy')&(m.time=='night')&(m.active=='movie'))
  def light(c):
    print('IF {0} {1} {2} THEN light=fluorescent lamp'.format(c.m.sky,c.m.time,c.m.active))

assert_fact('luminanace',{'sky':'sunny','time':'morning','active':'reading'})
assert_fact('luminanace',{'sky':'sunny','time':'morning','active':'sleeping'})
assert_fact('luminanace',{'sky':'sunny','time':'morning','active':'rest'})
assert_fact('luminanace',{'sky':'sunny','time':'morning','active':'movie'})
assert_fact('luminanace',{'sky':'sunny','time':'night','active':'reading'})
assert_fact('luminanace',{'sky':'sunny','time':'night','active':'sleeping'})
assert_fact('luminanace',{'sky':'sunny','time':'night','active':'rest'})
assert_fact('luminanace',{'sky':'sunny','time':'night','active':'movie'})
assert_fact('luminanace',{'sky':'cloudy','time':'morning','active':'reading'})
assert_fact('luminanace',{'sky':'cloudy','time':'morning','active':'sleeping'})
assert_fact('luminanace',{'sky':'cloudy','time':'morning','active':'rest'})
assert_fact('luminanace',{'sky':'cloudy','time':'morning','active':'movie'})
assert_fact('luminanace',{'sky':'cloudy','time':'night','active':'reading'})
assert_fact('luminanace',{'sky':'cloudy','time':'night','active':'sleeping'})
assert_fact('luminanace',{'sky':'cloudy','time':'night','active':'rest'})
assert_fact('luminanace',{'sky':'cloudy','time':'night','active':'movie'})
# Out:
# ...
# IF sunny morning reading THEN lux=200
# IF sunny morning reading THEN light=LED lamp
# IF sunny morning sleeping THEN lux=20
# IF sunny morning sleeping THEN light=fluorescent lamp
# IF sunny morning rest THEN lux=30
# IF sunny morning rest THEN light=fluorescent lamp
# IF sunny morning movie THEN lux=50
# IF sunny morning movie THEN light=fluorescent lamp
# IF sunny night reading THEN lux=400
# IF sunny night reading THEN light=LED lamp
# IF sunny night sleeping THEN lux=70
# IF sunny night sleeping THEN light=fluorescent lamp
# IF sunny night rest THEN lux=100
# IF sunny night rest THEN light=fluorescent lamp
# IF sunny night movie THEN lux=100
# IF sunny night movie THEN light=fluorescent lamp
# IF cloudy morning reading THEN lux=30
# IF cloudy morning sleeping THEN lux=50
# IF cloudy morning rest THEN lux=70
# IF cloudy morning movie THEN lux=70
# IF cloudy night reading THEN lux=400
# IF cloudy night reading THEN light=LED lamp
# IF cloudy night sleeping THEN lux=70
# ...
